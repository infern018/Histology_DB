# %%
import os
import zipfile
import json

# Path to the input directory and output file
input_dir = "server/ncbi_reports"  # Change this to your input directory
output_file_path = "combined_taxonomy_reports.json"  # Output file for combined data

output_data = []

def process_zip_file(zip_path):
    try:
        # Open the ZIP file
        with zipfile.ZipFile(zip_path, 'r') as zip_ref:
            # List all files in the ZIP
            zip_entries = zip_ref.namelist()

            # Find the taxonomy_report.jsonl inside the zip file
            jsonl_file = None
            for entry in zip_entries:
                if entry.startswith("ncbi_dataset/data/taxonomy_report.jsonl"):
                    jsonl_file = entry
                    break

            if jsonl_file:
                print(f"Processing {jsonl_file} from {zip_path}")

                # Extract the JSONL file content
                with zip_ref.open(jsonl_file) as f:
                    # Read the content of the JSONL file
                    for line in f:
                        try:
                            # Decode the line and parse it as JSON
                            json_data = json.loads(line.decode("utf-8"))
                            output_data.append(json_data)
                        except json.JSONDecodeError as e:
                            print(f"Error decoding JSON line in {jsonl_file}: {e}")
            else:
                print(f"No taxonomy_report.jsonl found in {zip_path}")
    except zipfile.BadZipFile as e:
        print(f"Error processing file {zip_path}: Bad ZIP file {e}")
    except Exception as e:
        print(f"Error processing file {zip_path}: {e}")

def main():
    try:
        # List all files in the input directory
        for file_name in os.listdir(input_dir):
            if file_name.endswith(".zip"):
                zip_path = os.path.join(input_dir, file_name)
                print(f"Processing file: {zip_path}")
                process_zip_file(zip_path)

        # After processing all ZIP files, save the combined data into a JSON file
        with open(output_file_path, 'w') as output_file:
            json.dump(output_data, output_file, indent=2)

        print(f"Combined taxonomy reports saved to: {output_file_path}")
    except Exception as e:
        print(f"Error during processing: {e}")

if __name__ == "__main__":
    main()
# Out:
# Processing file: server/ncbi_reports/ncbi_dataset_27658.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_27658.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9530.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9530.zip
# Processing file: server/ncbi_reports/ncbi_dataset_249015.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_249015.zip
# Processing file: server/ncbi_reports/ncbi_dataset_58073.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_58073.zip
# Processing file: server/ncbi_reports/ncbi_dataset_36225.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_36225.zip
# Processing file: server/ncbi_reports/ncbi_dataset_30640.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_30640.zip
# Processing file: server/ncbi_reports/ncbi_dataset_36231.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_36231.zip
# Processing file: server/ncbi_reports/ncbi_dataset_1206715.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_1206715.zip
# Processing file: server/ncbi_reports/ncbi_dataset_2830904.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_2830904.zip
# Processing file: server/ncbi_reports/ncbi_dataset_170214.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_170214.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9493.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9493.zip
# Processing file: server/ncbi_reports/ncbi_dataset_302404.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_302404.zip
# Processing file: server/ncbi_reports/ncbi_dataset_483426.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_483426.zip
# Processing file: server/ncbi_reports/ncbi_dataset_329870.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_329870.zip
# Processing file: server/ncbi_reports/ncbi_dataset_867881.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_867881.zip
# Processing file: server/ncbi_reports/ncbi_dataset_867842.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_867842.zip
# Processing file: server/ncbi_reports/ncbi_dataset_249028.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_249028.zip
# Processing file: server/ncbi_reports/ncbi_dataset_10036.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_10036.zip
# Processing file: server/ncbi_reports/ncbi_dataset_138696.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_138696.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9519.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9519.zip
# Processing file: server/ncbi_reports/ncbi_dataset_109475.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_109475.zip
# Processing file: server/ncbi_reports/ncbi_dataset_177183.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_177183.zip
# Processing file: server/ncbi_reports/ncbi_dataset_34828.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_34828.zip
# Processing file: server/ncbi_reports/ncbi_dataset_13515.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_13515.zip
# Processing file: server/ncbi_reports/ncbi_dataset_48897.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_48897.zip
# Processing file: server/ncbi_reports/ncbi_dataset_170217.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_170217.zip
# Processing file: server/ncbi_reports/ncbi_dataset_159322.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_159322.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9447.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9447.zip
# Processing file: server/ncbi_reports/ncbi_dataset_409053.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_409053.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9490.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9490.zip
# Processing file: server/ncbi_reports/ncbi_dataset_302412.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_302412.zip
# Processing file: server/ncbi_reports/ncbi_dataset_10141.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_10141.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9446.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9446.zip
# Processing file: server/ncbi_reports/ncbi_dataset_105689.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_105689.zip
# Processing file: server/ncbi_reports/ncbi_dataset_176115.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_176115.zip
# Processing file: server/ncbi_reports/ncbi_dataset_867841.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_867841.zip
# Processing file: server/ncbi_reports/ncbi_dataset_148038.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_148038.zip
# Processing file: server/ncbi_reports/ncbi_dataset_127560.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_127560.zip
# Processing file: server/ncbi_reports/ncbi_dataset_410852.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_410852.zip
# Processing file: server/ncbi_reports/ncbi_dataset_249003.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_249003.zip
# Processing file: server/ncbi_reports/ncbi_dataset_58065.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_58065.zip
# Processing file: server/ncbi_reports/ncbi_dataset_249017.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_249017.zip
# Processing file: server/ncbi_reports/ncbi_dataset_27672.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_27672.zip
# Processing file: server/ncbi_reports/ncbi_dataset_258867.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_258867.zip
# Processing file: server/ncbi_reports/ncbi_dataset_319813.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_319813.zip
# Processing file: server/ncbi_reports/ncbi_dataset_258863.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_258863.zip
# Processing file: server/ncbi_reports/ncbi_dataset_1001563.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_1001563.zip
# Processing file: server/ncbi_reports/ncbi_dataset_77243.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_77243.zip
# Processing file: server/ncbi_reports/ncbi_dataset_36223.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_36223.zip
# Processing file: server/ncbi_reports/ncbi_dataset_182682.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_182682.zip
# Processing file: server/ncbi_reports/ncbi_dataset_298110.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_298110.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9683.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9683.zip
# Processing file: server/ncbi_reports/ncbi_dataset_178896.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_178896.zip
# Processing file: server/ncbi_reports/ncbi_dataset_159858.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_159858.zip
# Processing file: server/ncbi_reports/ncbi_dataset_302402.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_302402.zip
# Processing file: server/ncbi_reports/ncbi_dataset_36800.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_36800.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9495.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9495.zip
# Processing file: server/ncbi_reports/ncbi_dataset_329863.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_329863.zip
# Processing file: server/ncbi_reports/ncbi_dataset_334198.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_334198.zip
# Processing file: server/ncbi_reports/ncbi_dataset_10151.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_10151.zip
# Processing file: server/ncbi_reports/ncbi_dataset_716695.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_716695.zip
# Processing file: server/ncbi_reports/ncbi_dataset_36801.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_36801.zip
# Processing file: server/ncbi_reports/ncbi_dataset_337453.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_337453.zip
# Processing file: server/ncbi_reports/ncbi_dataset_2720890.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_2720890.zip
# Processing file: server/ncbi_reports/ncbi_dataset_258889.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_258889.zip
# Processing file: server/ncbi_reports/ncbi_dataset_58060.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_58060.zip
# Processing file: server/ncbi_reports/ncbi_dataset_249012.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_249012.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9523.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9523.zip
# Processing file: server/ncbi_reports/ncbi_dataset_288699.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_288699.zip
# Processing file: server/ncbi_reports/ncbi_dataset_27663.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_27663.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9521.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9521.zip
# Processing file: server/ncbi_reports/ncbi_dataset_27661.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_27661.zip
# Processing file: server/ncbi_reports/ncbi_dataset_177185.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_177185.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9509.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9509.zip
# Processing file: server/ncbi_reports/ncbi_dataset_164648.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_164648.zip
# Processing file: server/ncbi_reports/ncbi_dataset_77240.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_77240.zip
# Processing file: server/ncbi_reports/ncbi_dataset_190508.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_190508.zip
# Processing file: server/ncbi_reports/ncbi_dataset_242384.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_242384.zip
# Processing file: server/ncbi_reports/ncbi_dataset_173903.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_173903.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9680.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9680.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9455.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9455.zip
# Processing file: server/ncbi_reports/ncbi_dataset_29076.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_29076.zip
# Processing file: server/ncbi_reports/ncbi_dataset_159324.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_159324.zip
# Processing file: server/ncbi_reports/ncbi_dataset_36803.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_36803.zip
# Processing file: server/ncbi_reports/ncbi_dataset_1207989.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_1207989.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9483.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9483.zip
# Processing file: server/ncbi_reports/ncbi_dataset_36802.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_36802.zip
# Processing file: server/ncbi_reports/ncbi_dataset_192726.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_192726.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9468.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9468.zip
# Processing file: server/ncbi_reports/ncbi_dataset_188568.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_188568.zip
# Processing file: server/ncbi_reports/ncbi_dataset_76836.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_76836.zip
# Processing file: server/ncbi_reports/ncbi_dataset_150088.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_150088.zip
# Processing file: server/ncbi_reports/ncbi_dataset_1837108.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_1837108.zip
# Processing file: server/ncbi_reports/ncbi_dataset_319815.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_319815.zip
# Processing file: server/ncbi_reports/ncbi_dataset_27660.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_27660.zip
# Processing file: server/ncbi_reports/ncbi_dataset_47180.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_47180.zip
# Processing file: server/ncbi_reports/ncbi_dataset_479477.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_479477.zip
# Processing file: server/ncbi_reports/ncbi_dataset_160448.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_160448.zip
# Processing file: server/ncbi_reports/ncbi_dataset_71119.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_71119.zip
# Processing file: server/ncbi_reports/ncbi_dataset_196889.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_196889.zip
# Processing file: server/ncbi_reports/ncbi_dataset_119564.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_119564.zip
# Processing file: server/ncbi_reports/ncbi_dataset_867834.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_867834.zip
# Processing file: server/ncbi_reports/ncbi_dataset_148071.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_148071.zip
# Processing file: server/ncbi_reports/ncbi_dataset_94963.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_94963.zip
# Processing file: server/ncbi_reports/ncbi_dataset_745256.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_745256.zip
# Processing file: server/ncbi_reports/ncbi_dataset_270768.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_270768.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9433.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9433.zip
# Processing file: server/ncbi_reports/ncbi_dataset_185215.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_185215.zip
# Processing file: server/ncbi_reports/ncbi_dataset_448084.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_448084.zip
# Processing file: server/ncbi_reports/ncbi_dataset_196296.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_196296.zip
# Processing file: server/ncbi_reports/ncbi_dataset_409033.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_409033.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9426.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9426.zip
# Processing file: server/ncbi_reports/ncbi_dataset_167044.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_167044.zip
# Processing file: server/ncbi_reports/ncbi_dataset_94962.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_94962.zip
# Processing file: server/ncbi_reports/ncbi_dataset_867821.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_867821.zip
# Processing file: server/ncbi_reports/ncbi_dataset_124747.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_124747.zip
# Processing file: server/ncbi_reports/ncbi_dataset_59455.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_59455.zip
# Processing file: server/ncbi_reports/ncbi_dataset_117602.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_117602.zip
# Processing file: server/ncbi_reports/ncbi_dataset_59482.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_59482.zip
# Processing file: server/ncbi_reports/ncbi_dataset_27638.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_27638.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9544.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9544.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9593.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9593.zip
# Processing file: server/ncbi_reports/ncbi_dataset_77231.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_77231.zip
# Processing file: server/ncbi_reports/ncbi_dataset_187005.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_187005.zip
# Processing file: server/ncbi_reports/ncbi_dataset_30608.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_30608.zip
# Processing file: server/ncbi_reports/ncbi_dataset_1833875.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_1833875.zip
# Processing file: server/ncbi_reports/ncbi_dataset_1496129.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_1496129.zip
# Processing file: server/ncbi_reports/ncbi_dataset_153297.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_153297.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9785.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9785.zip
# Processing file: server/ncbi_reports/ncbi_dataset_148066.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_148066.zip
# Processing file: server/ncbi_reports/ncbi_dataset_148072.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_148072.zip
# Processing file: server/ncbi_reports/ncbi_dataset_258959.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_258959.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9430.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9430.zip
# Processing file: server/ncbi_reports/ncbi_dataset_2093331.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_2093331.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9395.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9395.zip
# Processing file: server/ncbi_reports/ncbi_dataset_148073.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_148073.zip
# Processing file: server/ncbi_reports/ncbi_dataset_148067.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_148067.zip
# Processing file: server/ncbi_reports/ncbi_dataset_175523.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_175523.zip
# Processing file: server/ncbi_reports/ncbi_dataset_77218.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_77218.zip
# Processing file: server/ncbi_reports/ncbi_dataset_59456.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_59456.zip
# Processing file: server/ncbi_reports/ncbi_dataset_526818.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_526818.zip
# Processing file: server/ncbi_reports/ncbi_dataset_1868482.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_1868482.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9555.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9555.zip
# Processing file: server/ncbi_reports/ncbi_dataset_117605.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_117605.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9541.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9541.zip
# Processing file: server/ncbi_reports/ncbi_dataset_34899.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_34899.zip
# Processing file: server/ncbi_reports/ncbi_dataset_458326.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_458326.zip
# Processing file: server/ncbi_reports/ncbi_dataset_153286.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_153286.zip
# Processing file: server/ncbi_reports/ncbi_dataset_89673.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_89673.zip
# Processing file: server/ncbi_reports/ncbi_dataset_148063.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_148063.zip
# Processing file: server/ncbi_reports/ncbi_dataset_452596.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_452596.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9421.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9421.zip
# Processing file: server/ncbi_reports/ncbi_dataset_446905.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_446905.zip
# Processing file: server/ncbi_reports/ncbi_dataset_258948.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_258948.zip
# Processing file: server/ncbi_reports/ncbi_dataset_595220.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_595220.zip
# Processing file: server/ncbi_reports/ncbi_dataset_270785.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_270785.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9384.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9384.zip
# Processing file: server/ncbi_reports/ncbi_dataset_409020.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_409020.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9408.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9408.zip
# Processing file: server/ncbi_reports/ncbi_dataset_148089.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_148089.zip
# Processing file: server/ncbi_reports/ncbi_dataset_221087.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_221087.zip
# Processing file: server/ncbi_reports/ncbi_dataset_438766.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_438766.zip
# Processing file: server/ncbi_reports/ncbi_dataset_867827.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_867827.zip
# Processing file: server/ncbi_reports/ncbi_dataset_148062.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_148062.zip
# Processing file: server/ncbi_reports/ncbi_dataset_89672.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_89672.zip
# Processing file: server/ncbi_reports/ncbi_dataset_77235.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_77235.zip
# Processing file: server/ncbi_reports/ncbi_dataset_94435.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_94435.zip
# Processing file: server/ncbi_reports/ncbi_dataset_59453.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_59453.zip
# Processing file: server/ncbi_reports/ncbi_dataset_526821.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_526821.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9597.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9597.zip
# Processing file: server/ncbi_reports/ncbi_dataset_10090.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_10090.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9556.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9556.zip
# Processing file: server/ncbi_reports/ncbi_dataset_94437.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_94437.zip
# Processing file: server/ncbi_reports/ncbi_dataset_187003.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_187003.zip
# Processing file: server/ncbi_reports/ncbi_dataset_175524.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_175524.zip
# Processing file: server/ncbi_reports/ncbi_dataset_578340.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_578340.zip
# Processing file: server/ncbi_reports/ncbi_dataset_148074.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_148074.zip
# Processing file: server/ncbi_reports/ncbi_dataset_43780.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_43780.zip
# Processing file: server/ncbi_reports/ncbi_dataset_1002354.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_1002354.zip
# Processing file: server/ncbi_reports/ncbi_dataset_360967.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_360967.zip
# Processing file: server/ncbi_reports/ncbi_dataset_122246.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_122246.zip
# Processing file: server/ncbi_reports/ncbi_dataset_183661.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_183661.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9378.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9378.zip
# Processing file: server/ncbi_reports/ncbi_dataset_79805.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_79805.zip
# Processing file: server/ncbi_reports/ncbi_dataset_270786.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_270786.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9387.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9387.zip
# Processing file: server/ncbi_reports/ncbi_dataset_31869.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_31869.zip
# Processing file: server/ncbi_reports/ncbi_dataset_30586.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_30586.zip
# Processing file: server/ncbi_reports/ncbi_dataset_217708.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_217708.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9423.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9423.zip
# Processing file: server/ncbi_reports/ncbi_dataset_446907.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_446907.zip
# Processing file: server/ncbi_reports/ncbi_dataset_319527.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_319527.zip
# Processing file: server/ncbi_reports/ncbi_dataset_148049.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_148049.zip
# Processing file: server/ncbi_reports/ncbi_dataset_124756.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_124756.zip
# Processing file: server/ncbi_reports/ncbi_dataset_55054.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_55054.zip
# Processing file: server/ncbi_reports/ncbi_dataset_132108.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_132108.zip
# Processing file: server/ncbi_reports/ncbi_dataset_175525.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_175525.zip
# Processing file: server/ncbi_reports/ncbi_dataset_153284.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_153284.zip
# Processing file: server/ncbi_reports/ncbi_dataset_526822.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_526822.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9580.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9580.zip
# Processing file: server/ncbi_reports/ncbi_dataset_59487.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_59487.zip
# Processing file: server/ncbi_reports/ncbi_dataset_59461.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_59461.zip
# Processing file: server/ncbi_reports/ncbi_dataset_526813.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_526813.zip
# Processing file: server/ncbi_reports/ncbi_dataset_1081694.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_1081694.zip
# Processing file: server/ncbi_reports/ncbi_dataset_258947.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_258947.zip
# Processing file: server/ncbi_reports/ncbi_dataset_258952.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_258952.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9407.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9407.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9375.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9375.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9413.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9413.zip
# Processing file: server/ncbi_reports/ncbi_dataset_221088.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_221088.zip
# Processing file: server/ncbi_reports/ncbi_dataset_118855.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_118855.zip
# Processing file: server/ncbi_reports/ncbi_dataset_867814.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_867814.zip
# Processing file: server/ncbi_reports/ncbi_dataset_867828.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_867828.zip
# Processing file: server/ncbi_reports/ncbi_dataset_307107.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_307107.zip
# Processing file: server/ncbi_reports/ncbi_dataset_279181.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_279181.zip
# Processing file: server/ncbi_reports/ncbi_dataset_59460.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_59460.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9598.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9598.zip
# Processing file: server/ncbi_reports/ncbi_dataset_27619.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_27619.zip
# Processing file: server/ncbi_reports/ncbi_dataset_59476.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_59476.zip
# Processing file: server/ncbi_reports/ncbi_dataset_59462.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_59462.zip
# Processing file: server/ncbi_reports/ncbi_dataset_202257.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_202257.zip
# Processing file: server/ncbi_reports/ncbi_dataset_1378275.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_1378275.zip
# Processing file: server/ncbi_reports/ncbi_dataset_42254.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_42254.zip
# Processing file: server/ncbi_reports/ncbi_dataset_479723.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_479723.zip
# Processing file: server/ncbi_reports/ncbi_dataset_75567.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_75567.zip
# Processing file: server/ncbi_reports/ncbi_dataset_430492.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_430492.zip
# Processing file: server/ncbi_reports/ncbi_dataset_326083.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_326083.zip
# Processing file: server/ncbi_reports/ncbi_dataset_148090.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_148090.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9411.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9411.zip
# Processing file: server/ncbi_reports/ncbi_dataset_10116.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_10116.zip
# Processing file: server/ncbi_reports/ncbi_dataset_258945.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_258945.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9404.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9404.zip
# Processing file: server/ncbi_reports/ncbi_dataset_30576.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_30576.zip
# Processing file: server/ncbi_reports/ncbi_dataset_118856.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_118856.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9612.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9612.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9606.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9606.zip
# Processing file: server/ncbi_reports/ncbi_dataset_48988.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_48988.zip
# Processing file: server/ncbi_reports/ncbi_dataset_1496135.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_1496135.zip
# Processing file: server/ncbi_reports/ncbi_dataset_903567.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_903567.zip
# Processing file: server/ncbi_reports/ncbi_dataset_94439.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_94439.zip
# Processing file: server/ncbi_reports/ncbi_dataset_27634.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_27634.zip
# Processing file: server/ncbi_reports/ncbi_dataset_59467.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_59467.zip
# Processing file: server/ncbi_reports/ncbi_dataset_77215.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_77215.zip
# Processing file: server/ncbi_reports/ncbi_dataset_77229.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_77229.zip
# Processing file: server/ncbi_reports/ncbi_dataset_263451.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_263451.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9986.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9986.zip
# Processing file: server/ncbi_reports/ncbi_dataset_124749.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_124749.zip
# Processing file: server/ncbi_reports/ncbi_dataset_519039.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_519039.zip
# Processing file: server/ncbi_reports/ncbi_dataset_393601.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_393601.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9400.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9400.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9414.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9414.zip
# Processing file: server/ncbi_reports/ncbi_dataset_258940.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_258940.zip
# Processing file: server/ncbi_reports/ncbi_dataset_270766.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_270766.zip
# Processing file: server/ncbi_reports/ncbi_dataset_148094.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_148094.zip
# Processing file: server/ncbi_reports/ncbi_dataset_519038.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_519038.zip
# Processing file: server/ncbi_reports/ncbi_dataset_463804.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_463804.zip
# Processing file: server/ncbi_reports/ncbi_dataset_78866.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_78866.zip
# Processing file: server/ncbi_reports/ncbi_dataset_192405.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_192405.zip
# Processing file: server/ncbi_reports/ncbi_dataset_77214.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_77214.zip
# Processing file: server/ncbi_reports/ncbi_dataset_27621.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_27621.zip
# Processing file: server/ncbi_reports/ncbi_dataset_143289.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_143289.zip
# Processing file: server/ncbi_reports/ncbi_dataset_153298.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_153298.zip
# Processing file: server/ncbi_reports/ncbi_dataset_463806.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_463806.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9615.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9615.zip
# Processing file: server/ncbi_reports/ncbi_dataset_148041.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_148041.zip
# Processing file: server/ncbi_reports/ncbi_dataset_1091509.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_1091509.zip
# Processing file: server/ncbi_reports/ncbi_dataset_148069.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_148069.zip
# Processing file: server/ncbi_reports/ncbi_dataset_148082.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_148082.zip
# Processing file: server/ncbi_reports/ncbi_dataset_2029311.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_2029311.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9417.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9417.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9371.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9371.zip
# Processing file: server/ncbi_reports/ncbi_dataset_270770.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_270770.zip
# Processing file: server/ncbi_reports/ncbi_dataset_270764.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_270764.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9365.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9365.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9403.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9403.zip
# Processing file: server/ncbi_reports/ncbi_dataset_1286224.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_1286224.zip
# Processing file: server/ncbi_reports/ncbi_dataset_110941.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_110941.zip
# Processing file: server/ncbi_reports/ncbi_dataset_258957.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_258957.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9402.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9402.zip
# Processing file: server/ncbi_reports/ncbi_dataset_270771.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_270771.zip
# Processing file: server/ncbi_reports/ncbi_dataset_132908.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_132908.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9600.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9600.zip
# Processing file: server/ncbi_reports/ncbi_dataset_148040.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_148040.zip
# Processing file: server/ncbi_reports/ncbi_dataset_568173.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_568173.zip
# Processing file: server/ncbi_reports/ncbi_dataset_907075.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_907075.zip
# Processing file: server/ncbi_reports/ncbi_dataset_77217.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_77217.zip
# Processing file: server/ncbi_reports/ncbi_dataset_279184.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_279184.zip
# Processing file: server/ncbi_reports/ncbi_dataset_208972.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_208972.zip
# Processing file: server/ncbi_reports/ncbi_dataset_27622.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_27622.zip
# Processing file: server/ncbi_reports/ncbi_dataset_58085.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_58085.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9505.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9505.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9511.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9511.zip
# Processing file: server/ncbi_reports/ncbi_dataset_1833834.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_1833834.zip
# Processing file: server/ncbi_reports/ncbi_dataset_328804.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_328804.zip
# Processing file: server/ncbi_reports/ncbi_dataset_188571.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_188571.zip
# Processing file: server/ncbi_reports/ncbi_dataset_33546.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_33546.zip
# Processing file: server/ncbi_reports/ncbi_dataset_40225.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_40225.zip
# Processing file: server/ncbi_reports/ncbi_dataset_51300.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_51300.zip
# Processing file: server/ncbi_reports/ncbi_dataset_574065.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_574065.zip
# Processing file: server/ncbi_reports/ncbi_dataset_258930.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_258930.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9465.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9465.zip
# Processing file: server/ncbi_reports/ncbi_dataset_662898.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_662898.zip
# Processing file: server/ncbi_reports/ncbi_dataset_258925.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_258925.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9470.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9470.zip
# Processing file: server/ncbi_reports/ncbi_dataset_302395.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_302395.zip
# Processing file: server/ncbi_reports/ncbi_dataset_447135.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_447135.zip
# Processing file: server/ncbi_reports/ncbi_dataset_162630.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_162630.zip
# Processing file: server/ncbi_reports/ncbi_dataset_170234.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_170234.zip
# Processing file: server/ncbi_reports/ncbi_dataset_40224.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_40224.zip
# Processing file: server/ncbi_reports/ncbi_dataset_608659.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_608659.zip
# Processing file: server/ncbi_reports/ncbi_dataset_188570.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_188570.zip
# Processing file: server/ncbi_reports/ncbi_dataset_54292.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_54292.zip
# Processing file: server/ncbi_reports/ncbi_dataset_394056.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_394056.zip
# Processing file: server/ncbi_reports/ncbi_dataset_177163.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_177163.zip
# Processing file: server/ncbi_reports/ncbi_dataset_54133.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_54133.zip
# Processing file: server/ncbi_reports/ncbi_dataset_249009.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_249009.zip
# Processing file: server/ncbi_reports/ncbi_dataset_109481.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_109481.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9510.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9510.zip
# Processing file: server/ncbi_reports/ncbi_dataset_319819.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_319819.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9538.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9538.zip
# Processing file: server/ncbi_reports/ncbi_dataset_27646.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_27646.zip
# Processing file: server/ncbi_reports/ncbi_dataset_58079.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_58079.zip
# Processing file: server/ncbi_reports/ncbi_dataset_214442.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_214442.zip
# Processing file: server/ncbi_reports/ncbi_dataset_177161.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_177161.zip
# Processing file: server/ncbi_reports/ncbi_dataset_150086.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_150086.zip
# Processing file: server/ncbi_reports/ncbi_dataset_94117.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_94117.zip
# Processing file: server/ncbi_reports/ncbi_dataset_148965.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_148965.zip
# Processing file: server/ncbi_reports/ncbi_dataset_170236.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_170236.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9472.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9472.zip
# Processing file: server/ncbi_reports/ncbi_dataset_685783.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_685783.zip
# Processing file: server/ncbi_reports/ncbi_dataset_186990.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_186990.zip
# Processing file: server/ncbi_reports/ncbi_dataset_29078.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_29078.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9301.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9301.zip
# Processing file: server/ncbi_reports/ncbi_dataset_39082.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_39082.zip
# Processing file: server/ncbi_reports/ncbi_dataset_40233.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_40233.zip
# Processing file: server/ncbi_reports/ncbi_dataset_298109.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_298109.zip
# Processing file: server/ncbi_reports/ncbi_dataset_409885.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_409885.zip
# Processing file: server/ncbi_reports/ncbi_dataset_58078.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_58078.zip
# Processing file: server/ncbi_reports/ncbi_dataset_473867.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_473867.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9261.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9261.zip
# Processing file: server/ncbi_reports/ncbi_dataset_27647.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_27647.zip
# Processing file: server/ncbi_reports/ncbi_dataset_185453.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_185453.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9517.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9517.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9503.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9503.zip
# Processing file: server/ncbi_reports/ncbi_dataset_58083.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_58083.zip
# Processing file: server/ncbi_reports/ncbi_dataset_286131.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_286131.zip
# Processing file: server/ncbi_reports/ncbi_dataset_1582325.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_1582325.zip
# Processing file: server/ncbi_reports/ncbi_dataset_415933.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_415933.zip
# Processing file: server/ncbi_reports/ncbi_dataset_568927.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_568927.zip
# Processing file: server/ncbi_reports/ncbi_dataset_148021.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_148021.zip
# Processing file: server/ncbi_reports/ncbi_dataset_52814.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_52814.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9463.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9463.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9477.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9477.zip
# Processing file: server/ncbi_reports/ncbi_dataset_138707.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_138707.zip
# Processing file: server/ncbi_reports/ncbi_dataset_2748932.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_2748932.zip
# Processing file: server/ncbi_reports/ncbi_dataset_62280.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_62280.zip
# Processing file: server/ncbi_reports/ncbi_dataset_748910.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_748910.zip
# Processing file: server/ncbi_reports/ncbi_dataset_55149.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_55149.zip
# Processing file: server/ncbi_reports/ncbi_dataset_176119.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_176119.zip
# Processing file: server/ncbi_reports/ncbi_dataset_599854.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_599854.zip
# Processing file: server/ncbi_reports/ncbi_dataset_148034.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_148034.zip
# Processing file: server/ncbi_reports/ncbi_dataset_51298.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_51298.zip
# Processing file: server/ncbi_reports/ncbi_dataset_50353.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_50353.zip
# Processing file: server/ncbi_reports/ncbi_dataset_166054.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_166054.zip
# Processing file: server/ncbi_reports/ncbi_dataset_58069.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_58069.zip
# Processing file: server/ncbi_reports/ncbi_dataset_34825.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_34825.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9516.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9516.zip
# Processing file: server/ncbi_reports/ncbi_dataset_27642.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_27642.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9514.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9514.zip
# Processing file: server/ncbi_reports/ncbi_dataset_185454.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_185454.zip
# Processing file: server/ncbi_reports/ncbi_dataset_47177.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_47177.zip
# Processing file: server/ncbi_reports/ncbi_dataset_358128.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_358128.zip
# Processing file: server/ncbi_reports/ncbi_dataset_34827.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_34827.zip
# Processing file: server/ncbi_reports/ncbi_dataset_270698.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_270698.zip
# Processing file: server/ncbi_reports/ncbi_dataset_170230.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_170230.zip
# Processing file: server/ncbi_reports/ncbi_dataset_170224.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_170224.zip
# Processing file: server/ncbi_reports/ncbi_dataset_159339.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_159339.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9460.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9460.zip
# Processing file: server/ncbi_reports/ncbi_dataset_574060.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_574060.zip
# Processing file: server/ncbi_reports/ncbi_dataset_258909.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_258909.zip
# Processing file: server/ncbi_reports/ncbi_dataset_62283.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_62283.zip
# Processing file: server/ncbi_reports/ncbi_dataset_42147.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_42147.zip
# Processing file: server/ncbi_reports/ncbi_dataset_478698.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_478698.zip
# Processing file: server/ncbi_reports/ncbi_dataset_42146.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_42146.zip
# Processing file: server/ncbi_reports/ncbi_dataset_62282.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_62282.zip
# Processing file: server/ncbi_reports/ncbi_dataset_685785.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_685785.zip
# Processing file: server/ncbi_reports/ncbi_dataset_138705.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_138705.zip
# Processing file: server/ncbi_reports/ncbi_dataset_52631.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_52631.zip
# Processing file: server/ncbi_reports/ncbi_dataset_62902.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_62902.zip
# Processing file: server/ncbi_reports/ncbi_dataset_265733.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_265733.zip
# Processing file: server/ncbi_reports/ncbi_dataset_249018.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_249018.zip
# Processing file: server/ncbi_reports/ncbi_dataset_358129.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_358129.zip
# Combined taxonomy reports saved to: combined_taxonomy_reports.json
