# %%
import os
import zipfile
import json

# Paths
input_dir = "server/ncbi_reports"  # Input directory
output_file_path = "server/utils/combined_taxonomy_reports.json"  # Output file

output_data = []
unique_tax_ids = set()  # Track unique taxonomy codes

def load_existing_data():
    """Load existing data from the JSON file if it exists."""
    if os.path.exists(output_file_path):
        try:
            with open(output_file_path, "r") as f:
                data = json.load(f)
                # Extract and store unique tax_ids
                for entry in data:
                    tax_id = entry.get("tax_id")  # Adjust key name if different
                    if tax_id is not None:
                        unique_tax_ids.add(tax_id)
                return data
        except json.JSONDecodeError:
            print("Warning: Failed to decode existing JSON. Starting fresh.")
            return []
    return []

def process_zip_file(zip_path):
    """Process a ZIP file and extract new taxonomy data."""
    try:
        with zipfile.ZipFile(zip_path, "r") as zip_ref:
            zip_entries = zip_ref.namelist()

            # Find the taxonomy_report.jsonl inside the zip file
            jsonl_file = next((e for e in zip_entries if e.startswith("ncbi_dataset/data/taxonomy_report.jsonl")), None)

            if jsonl_file:
                print(f"Processing {jsonl_file} from {zip_path}")

                with zip_ref.open(jsonl_file) as f:
                    for line in f:
                        try:
                            json_data = json.loads(line.decode("utf-8"))
                            tax_id = json_data.get("tax_id")  # Adjust key name if different

                            # Ensure tax_id exists and is unique
                            if tax_id is not None and tax_id not in unique_tax_ids:
                                unique_tax_ids.add(tax_id)
                                output_data.append(json_data)
                        except json.JSONDecodeError as e:
                            print(f"Error decoding JSON line in {jsonl_file}: {e}")
            else:
                print(f"No taxonomy_report.jsonl found in {zip_path}")
    except zipfile.BadZipFile as e:
        print(f"Error processing file {zip_path}: Bad ZIP file {e}")
    except Exception as e:
        print(f"Error processing file {zip_path}: {e}")

def main():
    try:
        # Load existing data
        existing_data = load_existing_data()
        prev_count = len(existing_data)  # Count before processing

        # Process new ZIP files
        for file_name in os.listdir(input_dir):
            if file_name.endswith(".zip"):
                zip_path = os.path.join(input_dir, file_name)
                print(f"Processing file: {zip_path}")
                process_zip_file(zip_path)

        # Append new unique data and save
        combined_data = existing_data + output_data
        new_count = len(combined_data)  # Count after processing

        with open(output_file_path, "w") as output_file:
            json.dump(combined_data, output_file, indent=2)

        print(f"Updated taxonomy reports saved to: {output_file_path}")
        print(f"Previously, there were {prev_count} unique entries. Now, there are {new_count} unique entries.")
        print(f"Added {new_count - prev_count} new unique entries.")

    except Exception as e:
        print(f"Error during processing: {e}")

if __name__ == "__main__":
    main()
# Out:
# Processing file: server/ncbi_reports/ncbi_dataset_452646.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_452646.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9915.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9915.zip
# Processing file: server/ncbi_reports/ncbi_dataset_1206715.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_1206715.zip
# Processing file: server/ncbi_reports/ncbi_dataset_230844.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_230844.zip
# Processing file: server/ncbi_reports/ncbi_dataset_416366.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_416366.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9691.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9691.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9685.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9685.zip
# Processing file: server/ncbi_reports/ncbi_dataset_204263.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_204263.zip
# Processing file: server/ncbi_reports/ncbi_dataset_29073.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_29073.zip
# Processing file: server/ncbi_reports/ncbi_dataset_29067.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_29067.zip
# Processing file: server/ncbi_reports/ncbi_dataset_1960652.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_1960652.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9493.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9493.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9337.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9337.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9874.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9874.zip
# Processing file: server/ncbi_reports/ncbi_dataset_290563.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_290563.zip
# Processing file: server/ncbi_reports/ncbi_dataset_13515.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_13515.zip
# Processing file: server/ncbi_reports/ncbi_dataset_42410.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_42410.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9447.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9447.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9321.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9321.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9490.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9490.zip
# Processing file: server/ncbi_reports/ncbi_dataset_10141.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_10141.zip
# Processing file: server/ncbi_reports/ncbi_dataset_38632.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_38632.zip
# Processing file: server/ncbi_reports/ncbi_dataset_42411.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_42411.zip
# Processing file: server/ncbi_reports/ncbi_dataset_105689.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_105689.zip
# Processing file: server/ncbi_reports/ncbi_dataset_176115.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_176115.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9678.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9678.zip
# Processing file: server/ncbi_reports/ncbi_dataset_29139.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_29139.zip
# Processing file: server/ncbi_reports/ncbi_dataset_319813.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_319813.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9720.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9720.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9654.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9654.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9668.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9668.zip
# Processing file: server/ncbi_reports/ncbi_dataset_204265.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_204265.zip
# Processing file: server/ncbi_reports/ncbi_dataset_126295.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_126295.zip
# Processing file: server/ncbi_reports/ncbi_dataset_329863.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_329863.zip
# Processing file: server/ncbi_reports/ncbi_dataset_10151.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_10151.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9696.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9696.zip
# Processing file: server/ncbi_reports/ncbi_dataset_48850.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_48850.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9279.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9279.zip
# Processing file: server/ncbi_reports/ncbi_dataset_27675.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_27675.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9521.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9521.zip
# Processing file: server/ncbi_reports/ncbi_dataset_33562.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_33562.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9643.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9643.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9694.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9694.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9333.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9333.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9327.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9327.zip
# Processing file: server/ncbi_reports/ncbi_dataset_94247.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_94247.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9483.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9483.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9468.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9468.zip
# Processing file: server/ncbi_reports/ncbi_dataset_35660.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_35660.zip
# Processing file: server/ncbi_reports/ncbi_dataset_319815.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_319815.zip
# Processing file: server/ncbi_reports/ncbi_dataset_51342.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_51342.zip
# Processing file: server/ncbi_reports/ncbi_dataset_745256.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_745256.zip
# Processing file: server/ncbi_reports/ncbi_dataset_113277.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_113277.zip
# Processing file: server/ncbi_reports/ncbi_dataset_30554.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_30554.zip
# Processing file: server/ncbi_reports/ncbi_dataset_42713.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_42713.zip
# Processing file: server/ncbi_reports/ncbi_dataset_10041.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_10041.zip
# Processing file: server/ncbi_reports/ncbi_dataset_36723.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_36723.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9544.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9544.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9593.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9593.zip
# Processing file: server/ncbi_reports/ncbi_dataset_30608.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_30608.zip
# Processing file: server/ncbi_reports/ncbi_dataset_1833875.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_1833875.zip
# Processing file: server/ncbi_reports/ncbi_dataset_55047.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_55047.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9829.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9829.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9627.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9627.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9545.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9545.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9541.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9541.zip
# Processing file: server/ncbi_reports/ncbi_dataset_34899.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_34899.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9838.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9838.zip
# Processing file: server/ncbi_reports/ncbi_dataset_89672.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_89672.zip
# Processing file: server/ncbi_reports/ncbi_dataset_77235.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_77235.zip
# Processing file: server/ncbi_reports/ncbi_dataset_10047.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_10047.zip
# Processing file: server/ncbi_reports/ncbi_dataset_94435.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_94435.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9597.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9597.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9556.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9556.zip
# Processing file: server/ncbi_reports/ncbi_dataset_59479.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_59479.zip
# Processing file: server/ncbi_reports/ncbi_dataset_43179.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_43179.zip
# Processing file: server/ncbi_reports/ncbi_dataset_92522.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_92522.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9813.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9813.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9344.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9344.zip
# Processing file: server/ncbi_reports/ncbi_dataset_42716.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_42716.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9580.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9580.zip
# Processing file: server/ncbi_reports/ncbi_dataset_41010.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_41010.zip
# Processing file: server/ncbi_reports/ncbi_dataset_30548.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_30548.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9361.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9361.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9375.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9375.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9995.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9995.zip
# Processing file: server/ncbi_reports/ncbi_dataset_10060.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_10060.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9598.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9598.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9940.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9940.zip
# Processing file: server/ncbi_reports/ncbi_dataset_75567.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_75567.zip
# Processing file: server/ncbi_reports/ncbi_dataset_64683.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_64683.zip
# Processing file: server/ncbi_reports/ncbi_dataset_30589.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_30589.zip
# Processing file: server/ncbi_reports/ncbi_dataset_89252.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_89252.zip
# Processing file: server/ncbi_reports/ncbi_dataset_30576.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_30576.zip
# Processing file: server/ncbi_reports/ncbi_dataset_148052.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_148052.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9606.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9606.zip
# Processing file: server/ncbi_reports/ncbi_dataset_8487.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_8487.zip
# Processing file: server/ncbi_reports/ncbi_dataset_94439.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_94439.zip
# Processing file: server/ncbi_reports/ncbi_dataset_59463.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_59463.zip
# Processing file: server/ncbi_reports/ncbi_dataset_42731.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_42731.zip
# Processing file: server/ncbi_reports/ncbi_dataset_34884.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_34884.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9986.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9986.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9825.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9825.zip
# Processing file: server/ncbi_reports/ncbi_dataset_48422.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_48422.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9818.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9818.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9993.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9993.zip
# Processing file: server/ncbi_reports/ncbi_dataset_88029.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_88029.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9561.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9561.zip
# Processing file: server/ncbi_reports/ncbi_dataset_32560.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_32560.zip
# Processing file: server/ncbi_reports/ncbi_dataset_34844.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_34844.zip
# Processing file: server/ncbi_reports/ncbi_dataset_65612.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_65612.zip
# Processing file: server/ncbi_reports/ncbi_dataset_42520.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_42520.zip
# Processing file: server/ncbi_reports/ncbi_dataset_143302.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_143302.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9371.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9371.zip
# Processing file: server/ncbi_reports/ncbi_dataset_68732.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_68732.zip
# Processing file: server/ncbi_reports/ncbi_dataset_108855.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_108855.zip
# Processing file: server/ncbi_reports/ncbi_dataset_122272.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_122272.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9600.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9600.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9614.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9614.zip
# Processing file: server/ncbi_reports/ncbi_dataset_8495.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_8495.zip
# Processing file: server/ncbi_reports/ncbi_dataset_34886.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_34886.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9505.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9505.zip
# Processing file: server/ncbi_reports/ncbi_dataset_352831.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_352831.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9465.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9465.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9470.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9470.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9316.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9316.zip
# Processing file: server/ncbi_reports/ncbi_dataset_100937.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_100937.zip
# Processing file: server/ncbi_reports/ncbi_dataset_71006.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_71006.zip
# Processing file: server/ncbi_reports/ncbi_dataset_37696.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_37696.zip
# Processing file: server/ncbi_reports/ncbi_dataset_36239.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_36239.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9510.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9510.zip
# Processing file: server/ncbi_reports/ncbi_dataset_319819.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_319819.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9538.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9538.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9704.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9704.zip
# Processing file: server/ncbi_reports/ncbi_dataset_37737.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_37737.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9472.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9472.zip
# Processing file: server/ncbi_reports/ncbi_dataset_10149.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_10149.zip
# Processing file: server/ncbi_reports/ncbi_dataset_110931.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_110931.zip
# Processing file: server/ncbi_reports/ncbi_dataset_10160.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_10160.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9315.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9315.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9301.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9301.zip
# Processing file: server/ncbi_reports/ncbi_dataset_56323.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_56323.zip
# Processing file: server/ncbi_reports/ncbi_dataset_127582.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_127582.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9739.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9739.zip
# Processing file: server/ncbi_reports/ncbi_dataset_146632.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_146632.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9261.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9261.zip
# Processing file: server/ncbi_reports/ncbi_dataset_185453.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_185453.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9503.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9503.zip
# Processing file: server/ncbi_reports/ncbi_dataset_48086.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_48086.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9649.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9649.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9305.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9305.zip
# Processing file: server/ncbi_reports/ncbi_dataset_754486.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_754486.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9310.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9310.zip
# Processing file: server/ncbi_reports/ncbi_dataset_176119.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_176119.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9258.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9258.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9272.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9272.zip
# Processing file: server/ncbi_reports/ncbi_dataset_185454.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_185454.zip
# Processing file: server/ncbi_reports/ncbi_dataset_47177.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_47177.zip
# Processing file: server/ncbi_reports/ncbi_dataset_30670.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_30670.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9925.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9925.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9689.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9689.zip
# Processing file: server/ncbi_reports/ncbi_dataset_1000.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_1000.zip
# Processing file: server/ncbi_reports/ncbi_dataset_42152.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_42152.zip
# Processing file: server/ncbi_reports/ncbi_dataset_51338.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_51338.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9844.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9844.zip
# Processing file: server/ncbi_reports/ncbi_dataset_41261.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_41261.zip
# Processing file: server/ncbi_reports/ncbi_dataset_9267.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_9267.zip
# Processing file: server/ncbi_reports/ncbi_dataset_38775.zip
# Processing ncbi_dataset/data/taxonomy_report.jsonl from server/ncbi_reports/ncbi_dataset_38775.zip
# Updated taxonomy reports saved to: server/utils/combined_taxonomy_reports.json
# Previously, there were 560 unique entries. Now, there are 560 unique entries.
# Added 0 new unique entries.

# %%
# read combined_taxonomy_reports.json
import json

with open('/Users/vishwaas.singh/Documents/Personal/Projects/Histology_DB/server/utils/combined_taxonomy_reports.json') as f:
    data = json.load(f)

# %%
len(data)
# Out:
# 560
